# %% [markdown]
# ### Lectura de Datos

# %%
import pandas as pd

# %%
dataset = pd.read_csv("datos-tipo-cambio-usd-futuro-dolar-frecuencia-diaria_20181202.csv",parse_dates=['indice_tiempo'])

# %%
dataset.head(20)
# Out:
#    indice_tiempo  tipo_cambio_bna_vendedor  tipo_cambio_a3500  \
# 0     2002-03-05                       NaN             1.9917
# 1     2002-03-06                       NaN             2.0508
# 2     2002-03-07                       NaN             2.1375
# 3     2002-03-08                       NaN             2.2033
# 4     2002-03-09                       NaN             2.2033
# 5     2002-03-10                       NaN             2.2033
# 6     2002-03-11                       NaN             2.2525
# 7     2002-03-12                       NaN             2.3650
# 8     2002-03-13                       NaN             2.3317
# 9     2002-03-14                       NaN             2.3650
# 10    2002-03-15                       NaN             2.3408
# 11    2002-03-16                       NaN             2.3408
# 12    2002-03-17                       NaN             2.3408
# 13    2002-03-18                       NaN             2.3175
# 14    2002-03-19                       NaN             2.3783
# 15    2002-03-20                       NaN             2.4320
# 16    2002-03-21                       NaN             2.3883
# 17    2002-03-22                       NaN             2.5683
# 18    2002-03-23                       NaN             2.5683
# 19    2002-03-24                       NaN             2.5683
#
#     tipo_cambio_mae  volumen_mae  tipo_cambio_implicito_en_adrs  \
# 0               NaN          NaN                       2.180124
# 1               NaN          NaN                       2.222222
# 2               NaN          NaN                       2.343949
# 3               NaN          NaN                       2.227778
# 4               NaN          NaN                       2.227778
# 5               NaN          NaN                       2.227778
# 6               NaN          NaN                       2.253968
# 7               NaN          NaN                       2.367816
# 8               NaN          NaN                       2.348571
# 9               NaN          NaN                       2.343195
# 10              NaN          NaN                       2.362069
# 11              NaN          NaN                       2.362069
# 12              NaN          NaN                       2.362069
# 13              NaN          NaN                       2.426682
# 14              NaN          NaN                       2.460227
# 15              NaN          NaN                       2.730263
# 16              NaN          NaN                       2.570513
# 17              NaN          NaN                       2.921429
# 18              NaN          NaN                       2.921429
# 19              NaN          NaN                       2.921429
#
#     futuro_rofex_usd1m  interes_abierto_1m  futuro_rofex_usd2m  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# 5                  NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 7                  NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11                 NaN                 NaN                 NaN
# 12                 NaN                 NaN                 NaN
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
# 15                 NaN                 NaN                 NaN
# 16                 NaN                 NaN                 NaN
# 17                 NaN                 NaN                 NaN
# 18                 NaN                 NaN                 NaN
# 19                 NaN                 NaN                 NaN
#
#     interes_abierto_2m  futuro_rofex_usd3m  interes_abierto_3m  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# 5                  NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 7                  NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11                 NaN                 NaN                 NaN
# 12                 NaN                 NaN                 NaN
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
# 15                 NaN                 NaN                 NaN
# 16                 NaN                 NaN                 NaN
# 17                 NaN                 NaN                 NaN
# 18                 NaN                 NaN                 NaN
# 19                 NaN                 NaN                 NaN
#
#     futuro_rofex_usd4m  interes_abierto_4m  futuro_rofex_usd5m  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# 5                  NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 7                  NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11                 NaN                 NaN                 NaN
# 12                 NaN                 NaN                 NaN
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
# 15                 NaN                 NaN                 NaN
# 16                 NaN                 NaN                 NaN
# 17                 NaN                 NaN                 NaN
# 18                 NaN                 NaN                 NaN
# 19                 NaN                 NaN                 NaN
#
#     interes_abierto_5m  futuro_rofex_usd6m  interes_abierto_6m  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# 5                  NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 7                  NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11                 NaN                 NaN                 NaN
# 12                 NaN                 NaN                 NaN
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
# 15                 NaN                 NaN                 NaN
# 16                 NaN                 NaN                 NaN
# 17                 NaN                 NaN                 NaN
# 18                 NaN                 NaN                 NaN
# 19                 NaN                 NaN                 NaN
#
#     futuro_rofex_usd_12m  interes_abierto_12m
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# 5                    NaN                  NaN
# 6                    NaN                  NaN
# 7                    NaN                  NaN
# 8                    NaN                  NaN
# 9                    NaN                  NaN
# 10                   NaN                  NaN
# 11                   NaN                  NaN
# 12                   NaN                  NaN
# 13                   NaN                  NaN
# 14                   NaN                  NaN
# 15                   NaN                  NaN
# 16                   NaN                  NaN
# 17                   NaN                  NaN
# 18                   NaN                  NaN
# 19                   NaN                  NaN

# %%
dataset.describe()
# Out:
#        tipo_cambio_bna_vendedor  tipo_cambio_a3500  tipo_cambio_mae  \
# count               1474.000000        6100.000000      3789.000000
# mean                  16.292554           6.877798         9.195673
# std                    7.051349           6.407931         7.200433
# min                    8.490000           1.991700         3.012000
# 25%                    9.585000           3.084800         3.983000
# 50%                   15.500000           3.932800         5.702000
# 75%                   17.700000           8.412750        14.310000
# max                   41.250000          40.896700        41.250000
#
#         volumen_mae  tipo_cambio_implicito_en_adrs  futuro_rofex_usd1m  \
# count  2.554000e+03                    6100.000000         3604.000000
# mean   2.154285e+05                       7.581093            9.599868
# std    1.439476e+05                       6.607005            7.372371
# min    5.000000e+02                       2.180124            3.468000
# 25%    1.142775e+05                       3.078983            4.109750
# 50%    1.811800e+05                       3.965381            6.381500
# 75%    2.830750e+05                      11.709841           14.876250
# max    1.546850e+06                      41.545419           41.300000
#
#        interes_abierto_1m  futuro_rofex_usd2m  interes_abierto_2m  \
# count        3.604000e+03         3604.000000        3.604000e+03
# mean         6.580277e+05            9.802358        5.719712e+05
# std          4.782887e+05            7.628908        4.364505e+05
# min          1.300000e+01            3.508000        2.870000e+02
# 25%          3.763030e+05            4.137000        3.345380e+05
# 50%          5.364410e+05            6.651500        4.663410e+05
# 75%          7.633020e+05           15.181250        6.339335e+05
# max          3.517970e+06           43.200000        3.473273e+06
#
#        futuro_rofex_usd3m  interes_abierto_3m  futuro_rofex_usd4m  \
# count         3604.000000        3.604000e+03         3604.000000
# mean            10.001224        4.504577e+05           10.201910
# std              7.870440        4.066595e+05            8.113529
# min              3.549000        2.002200e+04            3.592000
# 25%              4.167000        2.706290e+05            4.200000
# 50%              6.849000        3.433520e+05            7.050500
# 75%             15.505000        4.866260e+05           15.821250
# max             45.050000        3.430609e+06           47.100000
#
#        interes_abierto_4m  futuro_rofex_usd5m  interes_abierto_5m  \
# count        3.604000e+03         3604.000000        3.604000e+03
# mean         3.571535e+05           10.402103        2.882788e+05
# std          3.668981e+05            8.345165        2.917788e+05
# min          3.279600e+04            3.628000        2.900000e+04
# 25%          1.961130e+05            4.236750        1.474040e+05
# 50%          2.609145e+05            7.250000        2.016570e+05
# 75%          3.750235e+05           16.101250        3.050010e+05
# max          3.436969e+06           48.700000        2.763188e+06
#
#        futuro_rofex_usd6m  interes_abierto_6m  futuro_rofex_usd_12m  \
# count         3604.000000        3.604000e+03           3604.000000
# mean            10.603774        2.397074e+05             11.750614
# std              8.573040        2.875439e+05              9.910212
# min              3.667000        1.711600e+04              3.895000
# 25%              4.278000        1.015338e+05              4.542000
# 50%              7.451500        1.647670e+05              6.100000
# 75%             16.380000        2.651650e+05             17.990000
# max             50.700000        2.766503e+06             58.000000
#
#        interes_abierto_12m
# count          3604.000000
# mean          25961.276915
# std           55450.019996
# min               1.000000
# 25%            1000.000000
# 50%            6100.000000
# 75%           31590.500000
# max          583103.000000

# %%
dataset.columns
# Out:
# Index(['indice_tiempo', 'tipo_cambio_bna_vendedor', 'tipo_cambio_a3500',
#        'tipo_cambio_mae', 'volumen_mae', 'tipo_cambio_implicito_en_adrs',
#        'futuro_rofex_usd1m', 'interes_abierto_1m', 'futuro_rofex_usd2m',
#        'interes_abierto_2m', 'futuro_rofex_usd3m', 'interes_abierto_3m',
#        'futuro_rofex_usd4m', 'interes_abierto_4m', 'futuro_rofex_usd5m',
#        'interes_abierto_5m', 'futuro_rofex_usd6m', 'interes_abierto_6m',
#        'futuro_rofex_usd_12m', 'interes_abierto_12m'],
#       dtype='object')

# %% [markdown]
# ### Para el análisis elijo usar la variable *"tipo_cambio_bna_vendedor"*

# %%
myDataSet = dataset.loc[:,['indice_tiempo', 'tipo_cambio_bna_vendedor']]
myDataSet.set_index('indice_tiempo',inplace=True)
myDataSet.head()
# Out:
#                tipo_cambio_bna_vendedor
# indice_tiempo
# 2002-03-05                          NaN
# 2002-03-06                          NaN
# 2002-03-07                          NaN
# 2002-03-08                          NaN
# 2002-03-09                          NaN

# %%
myDataSet.dtypes
# Out:
# tipo_cambio_bna_vendedor    float64
# dtype: object

# %% [markdown]
# ### Analisis de la variable *"tipo_cambio_bna_vendedor"*

# %%
import matplotlib.pyplot as plt

# %%
myDataSet.plot(figsize=[20,10],legend=False,)

# %%
myDataSet.boxplot(figsize=[10,10])

# %% [markdown]
# ### A partir del gráfico anterior se proponen los casos testigo:
#     C2: Años 2016, 2017
#     C3: Año 2018

# %% [markdown]
# ### Se analizan valores a partir del año 2016

# %%
initial_date = '2016-01-01'

# %%
myDataSet['month'] = myDataSet.index.month
myDataSet['year'] = myDataSet.index.year

groupData = myDataSet[myDataSet.index > initial_date].groupby(['year','month',]).mean()
groupData.head()
# Out:
#             tipo_cambio_bna_vendedor
# year month
# 2016 1                     13.786667
#      2                     14.927586
#      3                     15.117742
#      4                     14.623333
#      5                     14.329032

# %%
myDataSet.head()
# Out:
#                tipo_cambio_bna_vendedor  month  year
# indice_tiempo
# 2002-03-05                          NaN      3  2002
# 2002-03-06                          NaN      3  2002
# 2002-03-07                          NaN      3  2002
# 2002-03-08                          NaN      3  2002
# 2002-03-09                          NaN      3  2002

# %% [markdown]
# ### Filtrado de datos y eliminación de nulos, necesario para la aplicación de K-Means

# %%
X = myDataSet[myDataSet.index > initial_date].tipo_cambio_bna_vendedor.dropna()
X.head()
# Out:
# indice_tiempo
# 2016-01-02    13.3
# 2016-01-03    13.3
# 2016-01-04    13.3
# 2016-01-05    13.8
# 2016-01-06    14.0
# Name: tipo_cambio_bna_vendedor, dtype: float64

# %%
X.plot(figsize=[20,10],legend=False,)

# %% [markdown]
# ### Aplicación de Elbow Method para analizar cantidad óptima de clusters

# %%
X = pd.DataFrame(X)

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist
import numpy as np

# k means determine k
distortions = []

# Análsis con 10 clusters
N = range(1,10)

for n in N:
    kmeanModel = KMeans(n_clusters=n)
    kmeanModel.fit(X)
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])

# Plot the elbow
plt.plot(N, distortions, 'bx-')
plt.xlabel('n')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal n')
plt.show()

# %% [markdown]
# ### Aplicacion de método Silhouette para determinar número optimo de clusters

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import numpy as np

range_n_clusters = range(2,10)

for n_clusters in range_n_clusters:
    
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.7995578355324868
# For n_clusters = 3 The average silhouette_score is : 0.7820378531302924
# For n_clusters = 4 The average silhouette_score is : 0.6887473003642258
# For n_clusters = 5 The average silhouette_score is : 0.6907605178813566
# For n_clusters = 6 The average silhouette_score is : 0.6939230138460313
# For n_clusters = 7 The average silhouette_score is : 0.6701457682911394
# For n_clusters = 8 The average silhouette_score is : 0.6537573578991842
# For n_clusters = 9 The average silhouette_score is : 0.6624340708441162

# %% [markdown]
# ### Elbow method y silhuette indican que el mejor número de clusters es 3

# %% [markdown]
# ### Entreno K-Means con 3 clusters

# %%
kmeanModel = KMeans(n_clusters=3, verbose=0)
kmeanModel.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ### Visualización de elementos en cada cluster:

# %%
cluster_map = pd.DataFrame()
cluster_map['data_index'] = X.index.values
cluster_map['cluster'] = kmeanModel.labels_

# %% [markdown]
# ### Cluster 1

# %%
cluster_map[cluster_map.cluster == 0].head(20)
# Out:
#    data_index  cluster
# 0  2016-01-02        0
# 1  2016-01-03        0
# 2  2016-01-04        0
# 3  2016-01-05        0
# 4  2016-01-06        0
# 5  2016-01-07        0
# 6  2016-01-08        0
# 7  2016-01-09        0
# 8  2016-01-10        0
# 9  2016-01-11        0
# 10 2016-01-12        0
# 11 2016-01-13        0
# 12 2016-01-14        0
# 13 2016-01-15        0
# 14 2016-01-16        0
# 15 2016-01-17        0
# 16 2016-01-18        0
# 17 2016-01-19        0
# 18 2016-01-20        0
# 19 2016-01-21        0

# %% [markdown]
# ## Cluster 2

# %%
cluster_map[cluster_map.cluster == 1].head(20)
# Out:
#     data_index  cluster
# 970 2018-08-29        1
# 971 2018-08-30        1
# 972 2018-08-31        1
# 973 2018-09-01        1
# 974 2018-09-02        1
# 975 2018-09-03        1
# 976 2018-09-04        1
# 977 2018-09-05        1
# 978 2018-09-06        1
# 979 2018-09-07        1
# 980 2018-09-08        1
# 981 2018-09-09        1
# 982 2018-09-10        1
# 983 2018-09-11        1
# 984 2018-09-12        1
# 985 2018-09-13        1
# 986 2018-09-14        1
# 987 2018-09-15        1
# 988 2018-09-16        1
# 989 2018-09-17        1

# %% [markdown]
# ## Cluster 3

# %%
cluster_map[cluster_map.cluster == 2].head(20)
# Out:
#     data_index  cluster
# 852 2018-05-03        2
# 853 2018-05-04        2
# 854 2018-05-05        2
# 855 2018-05-06        2
# 856 2018-05-07        2
# 857 2018-05-08        2
# 858 2018-05-09        2
# 859 2018-05-10        2
# 860 2018-05-11        2
# 861 2018-05-12        2
# 862 2018-05-13        2
# 863 2018-05-14        2
# 864 2018-05-15        2
# 865 2018-05-16        2
# 866 2018-05-17        2
# 867 2018-05-18        2
# 868 2018-05-19        2
# 869 2018-05-20        2
# 870 2018-05-21        2
# 871 2018-05-22        2

# %% [markdown]
# Ordenando temporalmente los clusters vemos los períodos:
#
#     P1: 2016-01-02 -> 2018-05-02
#     P2: 2018-05-03 -> 2018-08-29
#     P3: 2018-08-30 -> 2018-12-02

# %% [markdown]
# ### Revisando nuevamente el gráfico anterior:

# %%
X.tipo_cambio_bna_vendedor.plot(figsize=[20,10],legend=False,)

# %% [markdown]
# Comparando los casos testigo iniciales con la clasificación propuesta por los clusters vemos que coinciden, lo que indique que para este tipo de problemas la técnica de clustering aplica perfectamente.

# %% [markdown]
# ### Visualizacion de centroides

# %%
print(kmeanModel.cluster_centers_)
# Out:
# [[16.42993662]
#  [37.28686076]
#  [26.82674576]]

# %% [markdown]
# Se puede ver que los valores de referencia segun el modelo son 16,42, 26,82 y 37.28
