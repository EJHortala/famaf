# %%
from keras import backend as K
K.set_session(K.tf.Session(config=K.tf.ConfigProto(intra_op_parallelism_threads=2, inter_op_parallelism_threads=2)))

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark')
import numpy as np
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = 16, 8
import warnings
warnings.simplefilter('ignore')
import gym
import time
from IPython.display import clear_output
import itertools

# %%
# se suaviza la curva de convergencia
def avg_reward(scores):
    episode_number = np.linspace(1, len(scores) + 1, len(scores) + 1)
    acumulated_rewards = np.cumsum(scores)
    return [acumulated_rewards[i] / episode_number[i] for i in range(len(acumulated_rewards))]

# %% [markdown]
# # Lab 2: Final
#
# Curso Aprendizaje por Refuerzos, Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones
#
# FaMAF, 2018

# %% [markdown]
# ## Introducción
#
# En el siguiente notebook se muestra cómo ejecutar agentes de aprendizaje por refuerzos que hacen uso de modelos matemáticos para aproximar una función de valor. Al utilizar este tipo de herramientas, aumentamos el riesgo de ver un comportamiento inestable y divergente durante el entrenamiento del agente. Esto se da en presencia de tres aspectos principales, llamados 'Triada Mortal':
#
# * Aproximación de funciones: es una forma poderosa y escalable de generalizar desde un espacio de estado mucho más grande que la memoria y los recursos computacionales (por ejemplo, aproximación de función lineal o Redes Neuronales Artificiales).
#
# * Bootstrapping: se actualizan objetivos que son dependientes de las estimaciones existentes (por ejemplo, en los métodos de TD) en lugar de depender exclusivamente de las recompensas reales y rendimientos completos (como en los métodos MC).
#
# * Off-Policy: Entrenamiento de un agente en base a una política diferente a la política objetivo (Por ejemplo Q-Learning).

# %% [markdown]
# ## CartPole: Agente aleatorio
# CartPole es un entorno donde un poste está unido por una unión no accionada a un carro, que se mueve a lo largo de una pista sin fricción. El sistema se controla aplicando una fuerza de +1 o -1 al carro. El péndulo comienza en posición vertical, y el objetivo es evitar que se caiga. Se proporciona una recompensa de +1 por cada paso de tiempo que el poste permanezca en posición vertical. El episodio termina cuando el poste está a más de 15 grados de la vertical, o el carro se mueve más de 2.4 unidades desde el centro.

# %% [markdown]
# env = gym.make('CartPole-v0')
# env.reset()
# for _ in range(250):
#     env.render(mode='human')
#     observation, reward, done, info = env.step(env.action_space.sample()) # se ejecuta una acción aleatoria
#     if done:
#         env.reset()
# env.close()
# clear_output()

# %% [markdown]
# ## CartPole: Aproximación con un modelo lineal
# A continuación analizaremos la implementación de un agente Q-Learning que utiliza como aproximador de la función de valor, un modelo lineal.
#
# Hay un gran problema con el uso de aproximadores para la función de valor $Q$. Las transiciones están muy correlacionadas. Esto reduce la varianza general de cada transición. Ya que toda la experiencia es extraída del mismo episodio (del actual).
#
# Imaginemos que tuviéramos que aprender una tarea sin memoria (ni siquiera a corto plazo), siempre optimizaría el aprendizaje en función del último episodio.
#
# El equipo de investigación de Google DeepMind utilizó lo que llamaron 'Experience Replay' para minimizar este problema. Esto es, en lugar de actualizar la función de valor con la última transición realizada, se almacena la misma en memoria y después de cada interacción del agente con el entorno, se entrena la función de valor con un lote de transiciones muestreadas al azar de la memoria de experiencia.

# %%
from agents.cart_pole_approx_vf import CartPole_SGD

agent = CartPole_SGD.SGDCartPoleSolver()
scores_SGD = agent.run()
# Out:
# [Episode 0] - Mean survival time over last 100 episodes was 19.0 ticks.
# [Episode 100] - Mean survival time over last 100 episodes was 20.73 ticks.
# [Episode 200] - Mean survival time over last 100 episodes was 16.58 ticks.
# [Episode 300] - Mean survival time over last 100 episodes was 14.92 ticks.
# [Episode 400] - Mean survival time over last 100 episodes was 13.95 ticks.
# [Episode 500] - Mean survival time over last 100 episodes was 13.02 ticks.
# [Episode 600] - Mean survival time over last 100 episodes was 12.31 ticks.
# [Episode 700] - Mean survival time over last 100 episodes was 11.8 ticks.
# [Episode 800] - Mean survival time over last 100 episodes was 12.1 ticks.
# [Episode 900] - Mean survival time over last 100 episodes was 11.36 ticks.
# [Episode 999] - Mean survival time over last 100 episodes was 11.16 ticks.

# %%
# se muestra el reward/score optenido por episodio
plt.plot(np.array(range(0, len(scores_SGD))), np.array(scores_SGD), label='SGD', c='#5c8cbc')
plt.ylim(0, 200)
plt.title('Recompensa por episodio')
plt.legend(loc='upper left')
plt.show()

# %%
reward_per_episode_SGD = avg_reward(scores_SGD)

plt.plot(reward_per_episode_SGD, label='SGD', c='#5c8cbc')
plt.ylim(0, 200)
plt.title('Recompensa promedio por episodio')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## CartPole: Aproximación con un modelo lineal con 'feature construction'
# Supongamos que un problema de aprendizaje por refuerzo tiene estados con dos dimensiones numéricas, donde para un estado $s$, sus dos componentes son $s_1 \in R$ y $s_2 \in R$.
#
# Si bien es posible elegir representar $s$ simplemente por las dos dimensiones del estado, de modo que $x(s)=(s_1, s_2)$; no obstante, no se puede tener en cuenta ninguna interacción entre estas dimensiones.
#
# Además, si tanto $s_1$ como $s_2$ son $0$, entonces el valor aproximado también será $0$, es decir $x(s)=0$. Ambas limitaciones se pueden superar representando $s$ por el vector de features polinómico $x(s)=(1,s_1,s_2,s_1s_2)$. El $1$ inicial, permite la representación de funciones afines en los números de estado originales, y el feature del producto final, $s_1 s_2$, permite que se tengan en cuenta dichas interacciones.
#
# También se podría utilizar un vector de features polinómico de mayor orden, como $x(s)=(1,s_1,s_2,s_1s_2,s_1^2,s_2^2,s_1s_2^2,s_1^2s_2,s_1^2s_2^2)$, para poder modelar interacciones más complejas.

# %%
from agents.cart_pole_approx_vf import CartPole_SGD_Poly

agent = CartPole_SGD_Poly.SGDPolyCartPoleSolver()
scores_SGD_Poly = agent.run()
# Out:
# [Episode 0] - Mean survival time over last 100 episodes was 17.0 ticks.
# [Episode 100] - Mean survival time over last 100 episodes was 25.85 ticks.
# [Episode 200] - Mean survival time over last 100 episodes was 22.98 ticks.
# [Episode 300] - Mean survival time over last 100 episodes was 19.44 ticks.
# [Episode 400] - Mean survival time over last 100 episodes was 19.55 ticks.
# [Episode 500] - Mean survival time over last 100 episodes was 19.44 ticks.
# [Episode 600] - Mean survival time over last 100 episodes was 20.05 ticks.
# [Episode 700] - Mean survival time over last 100 episodes was 20.19 ticks.
# [Episode 800] - Mean survival time over last 100 episodes was 22.16 ticks.
# [Episode 900] - Mean survival time over last 100 episodes was 22.34 ticks.
# [Episode 999] - Mean survival time over last 100 episodes was 21.5 ticks.

# %%
# se muestra el reward/score optenido por episodio
plt.plot(np.array(range(0, len(scores_SGD_Poly))), np.array(scores_SGD_Poly), label='SGD_Poly', c='#faa76c')
plt.plot(np.array(range(0, len(scores_SGD))), np.array(scores_SGD), label='SGD', c='#5c8cbc')
plt.ylim(0, 200)
plt.title('Recompensa por episodio')
plt.legend(loc='upper left')
plt.show()

# %%
reward_per_episode_SGD_Poly = avg_reward(scores_SGD_Poly)

plt.plot(reward_per_episode_SGD_Poly, label='SGD_Poly', c='#faa76c')
plt.plot(reward_per_episode_SGD, label='SGD', c='#5c8cbc')
plt.ylim(0, 200)
plt.title('Recompensa promedio por episodio')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## CartPole: Aproximación con un modelo lineal y 'Modelo Duplicado'
# El objetivo para una actualización de un algoritmo de control basado en TD, depende de la estimación actual ($w_{t}$). Donde el objetivo ($w_{t+1}$), es una función dependiente de los mismos parámetros que se están actualizando. Por ejemplo:
#
# $$w_{t+1}=w_t+\alpha[R_{t+1}+\gamma \operatorname*{max}_a\hat{q}(S_{t+1},a,w_t)-\hat{q}(S_t,A_t,w_t)]\nabla\hat{q}(S_t,A_t,w_t)$$
#
# Esta dependencia de $w_{t}$ complica el proceso en comparación con la situación más simple de aprendizaje supervisado, en la que los objetivos no dependen de los parámetros que se actualizan. Esto puede conducir a oscilaciones y/o divergencia.
#
# Para abordar este problema, el equipo de Google DeepMind desarrollo una solución para acercar el proceso de actualización de los parámetros ($w_t$) de un estimador, al caso mas simple utilizado en aprendizaje supervisado. Esto es, cada vez que se realizan un cierto número, $C$, de actualizaciones de los pesos $w$ en el predictor, se realiza una copia de los mismos en otro modelo (Modelo Duplicado o *Dual Model*), donde se mantienen estos pesos duplicados de forma fija para las próximas $C$ actualizaciones de $w$. Las estimaciones de este modelo duplicado, se utilizan como objetivo en la actualización de los pesos $w$, en las próximas $C$ actualizaciones:
#
# $$w_{t+1}=w_t+\alpha[R_{t+1}+\gamma \operatorname*{max}_a\underline{\tilde{q}(S_{t+1},a,w_t)}-\hat{q}(S_t,A_t,w_t)]\nabla\hat{q}(S_t,A_t,w_t)$$

# %%
from agents.cart_pole_approx_vf import CartPole_SGD_Poly_Dual

agent = CartPole_SGD_Poly_Dual.SGDPolyDualCartPoleSolver()
scores_SGD_Poly_Dual = agent.run()
# Out:
# [Episode 0] - Mean survival time over last 100 episodes was 21.0 ticks.
# [Episode 100] - Mean survival time over last 100 episodes was 27.02 ticks.
# [Episode 200] - Mean survival time over last 100 episodes was 30.8 ticks.
# [Episode 300] - Mean survival time over last 100 episodes was 67.09 ticks.
# [Episode 400] - Mean survival time over last 100 episodes was 158.53 ticks.
# [Episode 500] - Mean survival time over last 100 episodes was 175.74 ticks.
# [Episode 600] - Mean survival time over last 100 episodes was 169.8 ticks.
# [Episode 700] - Mean survival time over last 100 episodes was 161.55 ticks.
# [Episode 800] - Mean survival time over last 100 episodes was 164.44 ticks.
# [Episode 900] - Mean survival time over last 100 episodes was 161.94 ticks.
# [Episode 999] - Mean survival time over last 100 episodes was 168.5 ticks.

# %%
# se muestra el reward/score optenido por episodio
plt.plot(np.array(range(0, len(scores_SGD_Poly_Dual))), np.array(scores_SGD_Poly_Dual), label='SGD_Poly_Dual', c='#71bc78')
plt.plot(np.array(range(0, len(scores_SGD_Poly))), np.array(scores_SGD_Poly), label='SGD_Poly', c='#faa76c')
plt.plot(np.array(range(0, len(scores_SGD))), np.array(scores_SGD), label='SGD', c='#5c8cbc')
plt.ylim(0, 200)
plt.title('Recompensa por episodio')
plt.legend(loc='upper left')
plt.show()

# %%
reward_per_episode_SGD_Poly_Dual = avg_reward(scores_SGD_Poly_Dual)
plt.plot(reward_per_episode_SGD_Poly_Dual, label='SGD_Poly_Dual', c='#71bc78')
plt.plot(reward_per_episode_SGD_Poly, label='SGD_Poly', c='#faa76c')
plt.plot(reward_per_episode_SGD, label='SGD', c='#5c8cbc')
plt.ylim(0, 200)
plt.title('Recompensa promedio por episodio')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## CartPole: Aproximación con Redes Neuronales
# Como ultima mejora, vamos a reemplazar el aproximador lineal por una red neuronal. Para el caso del CartPole, estamos trabajando con un entorno donde el agente percibe directamente los features que representan el estado del mismo. En otras palabras, como nuestro agente no percibe el estado del entorno a través de una sucesión de imágenes, no es necesario que nuestra red cuente con capas convolucionales que generen features del entorno. Por lo tanto, utilizaremos una red neuronal 'fully connected' de 3 capas con la siguiente arquitectura:
#
# ![nn_dense](images/nn_dense.png)
#
# En este caso, como el aproximador usado es 'no lineal', no tenemos necesidad de hacer un pre-prosesamiento de los features, como en el caso del agente 'SGD_Poly' y 'SGD_Poly_Dual', para poder capturar las relaciones no lineales entre los distintos features del entorno.

# %% [markdown]
# ### Funciones de activación:
# ![activation_functions](images/activation_functions.png)

# %%
from agents.cart_pole_approx_vf import CartPole_DQN

agent = CartPole_DQN.DQNCartPoleSolver()
scores_DQN = agent.run()
# Out:
# Using TensorFlow backend.
# [Episode 0] - Mean survival time over last 100 episodes was 16.0 ticks.
# [Episode 100] - Mean survival time over last 100 episodes was 40.13 ticks.
# [Episode 200] - Mean survival time over last 100 episodes was 116.68 ticks.
# [Episode 300] - Mean survival time over last 100 episodes was 185.36 ticks.
# [Episode 400] - Mean survival time over last 100 episodes was 197.25 ticks.
# [Episode 500] - Mean survival time over last 100 episodes was 193.68 ticks.
# [Episode 600] - Mean survival time over last 100 episodes was 195.69 ticks.
# [Episode 700] - Mean survival time over last 100 episodes was 195.27 ticks.
# [Episode 800] - Mean survival time over last 100 episodes was 195.33 ticks.
# [Episode 900] - Mean survival time over last 100 episodes was 195.67 ticks.
# [Episode 999] - Mean survival time over last 100 episodes was 196.43 ticks.

# %%
# se muestra el reward/score optenido por episodio
plt.plot(np.array(range(0, len(scores_DQN))), np.array(scores_DQN), label='DQN', c='#7e5fa4')
plt.plot(np.array(range(0, len(scores_SGD_Poly_Dual))), np.array(scores_SGD_Poly_Dual), label='SGD_Poly_Dual', c='#71bc78')
plt.plot(np.array(range(0, len(scores_SGD_Poly))), np.array(scores_SGD_Poly), label='SGD_Poly', c='#faa76c')
plt.plot(np.array(range(0, len(scores_SGD))), np.array(scores_SGD), label='SGD', c='#5c8cbc')
plt.ylim(0, 200)
plt.title('Recompensa por episodio')
plt.legend(loc='upper left')
plt.show()

# %%
reward_per_episode_DQN = avg_reward(scores_DQN)
plt.plot(reward_per_episode_DQN, label='DQN', c='#7e5fa4')
plt.plot(reward_per_episode_SGD_Poly_Dual, label='SGD_Poly_Dual', c='#71bc78')
plt.plot(reward_per_episode_SGD_Poly, label='SGD_Poly', c='#faa76c')
plt.plot(reward_per_episode_SGD, label='SGD', c='#5c8cbc')
plt.ylim(0, 200)
plt.title('Recompensa promedio por episodio')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Ejercicios Lab Final
#
# Se pide:
#
# 1) Dado el agente que utiliza una red neuronal para aproximar la función de valor, modificar la arquitectura de la misma en busca de una mejora en el desempeño del agente. La modificaciones a realizar puede ser:
#     * Agregar mas capas ocultas a la red
#     * Modificar las funciones de activación de las neuronas
#     * Modificar el numero de neuronas en cada capa
#
# **Recomendación #1**: Tener en cuenta que al incorporar mas capas y neuronas a una red neuronal, mas complejidad computacional se incorpora al modelo, lo que se traduce en una mayor duración (en tiempo) del entrenamiento del agente.
#
# **Recomendación #2**: Una métrica eficiente para comparar del desempeño de diferentes agentes es la curva de "reward promedio acumulado". Esta métrica permite visualizar el desempeño general del agente, como así también la rapidez (cantidad de episodios) que requiere un agente para alcanzar un determinado desempeño.
#
# **Recomendación #3**: Al modificar distintos aspecto de la arquitectura del aproximador, realizar de a un cambio por evaluación.
#
# 2) Adaptar los agentes implementados en el notebook (incluido el implementado por ustedes) al entorno 'MountainCar-v0' (http://gym.openai.com/envs/MountainCar-v0/) y comparar el desempeño de los mismos.
#
# 3) Elaborar un informe que enumere lo realizado paso a paso, mostrando resultados parciales y finales.
#
# **Recomendación General**: No se sugiere hacer este TP desde jupyter notebook/lab sino desde un IDE estilo Pycharm, debido a que los algoritmos de RL suelen requerir un debug paso a paso, tanto para corregir errores como para entender mejor cómo funcionan los mismos.

# %% [markdown]
# Se plantearon 4 arquitecturas de red diferentes analizando la cantidad veces que el auto llega a la cima luego de balancearse.
# Los modelos analizados incluyeron cambios en la cantidad de capas, neuronas por capa y variantes en la funcion de activación, descartando este último
# cambio por tener resultados adversos.

# %% [markdown]
# # Original model

# %%
from agents.cart_pole_approx_vf import CartPole_DQN

agent = CartPole_DQN.DQNCartPoleSolver()
scores_DQN = agent.run()
# Out:
# [Episode 0] - Mean survival time over last 100 episodes was 13.0 ticks.
# [Episode 100] - Mean survival time over last 100 episodes was 41.76 ticks.
# [Episode 200] - Mean survival time over last 100 episodes was 103.78 ticks.
# [Episode 300] - Mean survival time over last 100 episodes was 155.55 ticks.
# [Episode 400] - Mean survival time over last 100 episodes was 159.28 ticks.
# [Episode 500] - Mean survival time over last 100 episodes was 158.12 ticks.
# [Episode 600] - Mean survival time over last 100 episodes was 157.66 ticks.
# [Episode 700] - Mean survival time over last 100 episodes was 166.09 ticks.
# [Episode 800] - Mean survival time over last 100 episodes was 175.44 ticks.
# [Episode 900] - Mean survival time over last 100 episodes was 188.31 ticks.
# [Episode 999] - Mean survival time over last 100 episodes was 194.91 ticks.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark')
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = 16, 8

reward_per_episode_DQN = avg_reward(scores_DQN)
plt.plot(reward_per_episode_DQN, label='DQN', c='#7e5fa4')
plt.ylim(0, 200)
plt.title('Recompensa promedio por episodio')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Model 1 (3 capas con 16 neuronas)

# %%
from agents.cart_pole_approx_vf import CartPole_DQN

agent = CartPole_DQN.DQNCartPoleSolver()
scores_DQN = agent.run()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 16)                80
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 658
# Trainable params: 658
# Non-trainable params: 0
# _________________________________________________________________
# None
# [Episode 0] - Mean survival time over last 100 episodes was 14.0 ticks.
# [Episode 100] - Mean survival time over last 100 episodes was 41.42 ticks.
# [Episode 200] - Mean survival time over last 100 episodes was 108.73 ticks.
# [Episode 300] - Mean survival time over last 100 episodes was 158.97 ticks.
# [Episode 400] - Mean survival time over last 100 episodes was 173.92 ticks.
# [Episode 500] - Mean survival time over last 100 episodes was 168.3 ticks.
# [Episode 600] - Mean survival time over last 100 episodes was 166.98 ticks.
# [Episode 700] - Mean survival time over last 100 episodes was 168.55 ticks.
# [Episode 800] - Mean survival time over last 100 episodes was 165.07 ticks.
# [Episode 900] - Mean survival time over last 100 episodes was 164.37 ticks.
# [Episode 999] - Mean survival time over last 100 episodes was 159.14 ticks.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark')
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = 16, 8

reward_per_episode_DQN = avg_reward(scores_DQN)
plt.plot(reward_per_episode_DQN, label='DQN', c='#7e5fa4')
plt.ylim(0, 200)
plt.title('Recompensa promedio por episodio')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Model 2 (Modelo original con menos neuronas por capa)

# %%
from agents.cart_pole_approx_vf import CartPole_DQN

agent = CartPole_DQN.DQNCartPoleSolver()
scores_DQN = agent.run()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 16)                80
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                544
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 690
# Trainable params: 690
# Non-trainable params: 0
# _________________________________________________________________
# None
# [Episode 0] - Mean survival time over last 100 episodes was 14.0 ticks.
# [Episode 100] - Mean survival time over last 100 episodes was 36.74 ticks.
# [Episode 200] - Mean survival time over last 100 episodes was 106.07 ticks.
# [Episode 300] - Mean survival time over last 100 episodes was 155.72 ticks.
# [Episode 400] - Mean survival time over last 100 episodes was 162.11 ticks.
# [Episode 500] - Mean survival time over last 100 episodes was 166.29 ticks.
# [Episode 600] - Mean survival time over last 100 episodes was 168.35 ticks.
# [Episode 700] - Mean survival time over last 100 episodes was 171.67 ticks.
# [Episode 800] - Mean survival time over last 100 episodes was 174.52 ticks.
# [Episode 900] - Mean survival time over last 100 episodes was 184.96 ticks.
# [Episode 999] - Mean survival time over last 100 episodes was 185.91 ticks.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark')
# %matplotlib inline
import matplotlib
import numpy as np
matplotlib.rcParams['figure.figsize'] = 16, 8

reward_per_episode_DQN = avg_reward(scores_DQN)
plt.plot(reward_per_episode_DQN, label='DQN', c='#7e5fa4')
plt.ylim(0, 200)
plt.title('Recompensa promedio por episodio')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Model 3 (2 capas con mas neuronas)

# %%
from agents.cart_pole_approx_vf import CartPole_DQN
agent = None
agent = CartPole_DQN.DQNCartPoleSolver()
scores_DQN = agent.run()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                160
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 2,402
# Trainable params: 2,402
# Non-trainable params: 0
# _________________________________________________________________
# None
# [Episode 0] - Mean survival time over last 100 episodes was 12.0 ticks.
# [Episode 100] - Mean survival time over last 100 episodes was 33.49 ticks.
# [Episode 200] - Mean survival time over last 100 episodes was 94.29 ticks.
# [Episode 300] - Mean survival time over last 100 episodes was 154.68 ticks.
# [Episode 400] - Mean survival time over last 100 episodes was 196.28 ticks.
# [Episode 500] - Mean survival time over last 100 episodes was 199.19 ticks.
# [Episode 600] - Mean survival time over last 100 episodes was 199.96 ticks.
# [Episode 700] - Mean survival time over last 100 episodes was 200.0 ticks.
# [Episode 800] - Mean survival time over last 100 episodes was 200.0 ticks.
# [Episode 900] - Mean survival time over last 100 episodes was 200.0 ticks.
# [Episode 999] - Mean survival time over last 100 episodes was 200.0 ticks.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark')
# %matplotlib inline
import matplotlib
import numpy as np
matplotlib.rcParams['figure.figsize'] = 16, 8

reward_per_episode_DQN = avg_reward(scores_DQN)
plt.plot(reward_per_episode_DQN, label='DQN', c='#7e5fa4')
plt.ylim(0, 200)
plt.title('Recompensa promedio por episodio')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Model 4 (Agrego capa al modelo original)

# %%
from agents.cart_pole_approx_vf import CartPole_DQN
agent = None
agent = CartPole_DQN.DQNCartPoleSolver()
scores_DQN = agent.run()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_2 (Dense)              (None, 48)                1200
# _________________________________________________________________
# dense_3 (Dense)              (None, 24)                1176
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 50
# =================================================================
# Total params: 2,546
# Trainable params: 2,546
# Non-trainable params: 0
# _________________________________________________________________
# None
# [Episode 0] - Mean survival time over last 100 episodes was 12.0 ticks.
# [Episode 100] - Mean survival time over last 100 episodes was 41.46 ticks.
# [Episode 200] - Mean survival time over last 100 episodes was 137.24 ticks.
# [Episode 300] - Mean survival time over last 100 episodes was 188.22 ticks.
# [Episode 400] - Mean survival time over last 100 episodes was 198.29 ticks.
# [Episode 500] - Mean survival time over last 100 episodes was 199.88 ticks.
# [Episode 600] - Mean survival time over last 100 episodes was 199.62 ticks.
# [Episode 700] - Mean survival time over last 100 episodes was 199.94 ticks.
# [Episode 800] - Mean survival time over last 100 episodes was 198.98 ticks.
# [Episode 900] - Mean survival time over last 100 episodes was 195.52 ticks.
# [Episode 999] - Mean survival time over last 100 episodes was 193.24 ticks.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark')
# %matplotlib inline
import matplotlib
import numpy as np
matplotlib.rcParams['figure.figsize'] = 16, 8

reward_per_episode_DQN = avg_reward(scores_DQN)
plt.plot(reward_per_episode_DQN, label='DQN', c='#7e5fa4')
plt.ylim(0, 200)
plt.title('Recompensa promedio por episodio')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Model 5 (Cambio funcion de activación)

# %%
from agents.cart_pole_approx_vf import CartPole_DQN
agent = None
agent = CartPole_DQN.DQNCartPoleSolver()
scores_DQN = agent.run()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_2 (Dense)              (None, 48)                1200
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 98
# =================================================================
# Total params: 1,418
# Trainable params: 1,418
# Non-trainable params: 0
# _________________________________________________________________
# None
# [Episode 0] - Mean survival time over last 100 episodes was 14.0 ticks.
# [Episode 100] - Mean survival time over last 100 episodes was 20.52 ticks.
# [Episode 200] - Mean survival time over last 100 episodes was 21.0 ticks.
# [Episode 300] - Mean survival time over last 100 episodes was 20.67 ticks.
# [Episode 400] - Mean survival time over last 100 episodes was 15.35 ticks.
# [Episode 500] - Mean survival time over last 100 episodes was 12.16 ticks.
# [Episode 600] - Mean survival time over last 100 episodes was 12.38 ticks.
# [Episode 700] - Mean survival time over last 100 episodes was 10.72 ticks.
# [Episode 800] - Mean survival time over last 100 episodes was 9.89 ticks.
# [Episode 900] - Mean survival time over last 100 episodes was 9.35 ticks.
# [Episode 999] - Mean survival time over last 100 episodes was 9.4 ticks.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark')
# %matplotlib inline
import matplotlib
import numpy as np
matplotlib.rcParams['figure.figsize'] = 16, 8

reward_per_episode_DQN = avg_reward(scores_DQN)
plt.plot(reward_per_episode_DQN, label='DQN', c='#7e5fa4')
plt.ylim(0, 200)
plt.title('Recompensa promedio por episodio')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Luego de ejecutar varias arquitecturas de red neuronal se observa que las configuraciones de red que incluyen mayor cantidad de neuronas por capa alcanzan el objetivo mas rapidamente que las demas.
# También se observa una mejora al agregar mas capas a la red, aunque no tan significativa como el agegado de mas neuronas a cada capa.
# Resulta interesante ver que una misma configuración de red con diferentes funciones de activación puede tener desempeños muy diferentes, como así tambien sus tiempos de ejecución.
# Se observa una relación directa entre cantidad de parámetros entrenables y desempeño de la red y tiempo de ejecución.
# Como resultado final se concluye que los modelos neuronales en general producen mejores resultados que lo modelos lineales y polinomiales, siendo el modelo mas cercano en resultadosel polinomial dual. Igualmente, dependiendo del problema puede optarse por un modelo mas sencillo considerando la gran diferencia en tiempo de entrenamiento entre estas soluciones.
